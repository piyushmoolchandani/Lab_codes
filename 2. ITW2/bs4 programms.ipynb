# %%
import requests
import re
import bs4 as bs
from bs4 import BeautifulSoup as make_soup

# %%
url = 'https://pythonprogramming.net/parsememcparseface/'
soup = make_soup(requests.get(url).content, 'html5lib')

# %% [markdown]
# * Prettify()

# %%
a = make_soup('<b>Hey<b>')

# %%
a
# Out:
# <html><body><b>Hey<b></b></b></body></html>

# %%
print(a.prettify())
# Out:
# <html>
#  <body>
#   <b>
#    Hey
#    <b>
#    </b>
#   </b>
#  </body>
# </html>

# %% [markdown]
# ### Program 1: Extract all the quotes from a Website (Uses html)

# %%
url = 'https://www.brainyquote.com/top_100_quotes'
doc = requests.get(url).content
soup = bs.BeautifulSoup(doc)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-ng-app="bqApp" lang="en">
#  <head>
#   <title>
#    The Top 100 QUOTES of All Time - BrainyQuote
#   </title>
#   <meta content="all" name="robots"/>
#   <meta charset="utf-8"/>
#   <link href="//www.google-analytics.com" rel="dns-prefetch"/>
#   <link href="//googletagservices.com" rel="dns-prefetch"/>
#   <link href="//ad.doubleclick.net" rel="dns-prefetch"/>
#   <link href="//pagead2.googlesyndication.com" rel="dns-prefetch"/>
#   <link href="//partner.googleadservices.com" rel="dns-prefetch"/>
#   <link href="//brainyquote-d.openx.net" rel="dns-prefetch"/>
#   <link href="//js.indexww.com" rel="dns-prefetch"/>
#   <link href="//as.casalemedia.com/" rel="dns-prefetch"/>
#   <link href="//c.amazon-adsystem.com" rel="dns-prefetch"/>
#   <link href="//fls-na.amazon-adsystem.com" rel="dns-prefetch"/>
#   <link href="//z-na.amazon-adsystem.com" rel="dns-prefetch"/>
#   <link href="//rcm-na.amazon-adsystem.com" rel="dns-prefetch"/>
# ...

# %%
quotes = []
for i in soup.select("[class=block-quote]"):
    quotes.append((i.text, i.find_next(class_ = 'block-author').text))

# %%
for i in quotes:
    print(i[0], i[1])
    print('-------------------------------------------------------------')
# Out:
# I love you the more in that I believe you had liked me for my own sake and for nothing else.
#
# John Keats
#
# -------------------------------------------------------------
#
# But man is not made for defeat. A man can be destroyed but not defeated.
#
# Ernest Hemingway
#
# -------------------------------------------------------------
#
# When you reach the end of your rope, tie a knot in it and hang on.
#
# Franklin D. Roosevelt
#
# -------------------------------------------------------------
#
# There is nothing permanent except change.
#
# Heraclitus
#
# -------------------------------------------------------------
#
# You cannot shake hands with a clenched fist.
#
# Indira Gandhi
#
# -------------------------------------------------------------
#
# Let us sacrifice our today so that our children can have a better tomorrow.
#
# A. P. J. Abdul Kalam
#
# -------------------------------------------------------------
#
# ...

# %% [markdown]
# ### Program 2: Extract a table (Uses html)

# %%
# HTML table: 
# <table>
#     <tbody>
#         <tr>
#             <td> string </td>
#         </tr>
#     </tbody>
# </table>

# %%
url = 'https://pythonprogramming.net/parsememcparseface/'
soup = make_soup(requests.get(url).content, 'html5lib')
table = soup.table

# %%
row = [[i.text for i in row_.find_all('td')] for row_ in table.find_all('tr')]
for i in row:
    print(i)
# Out:
# []
# ['Python', '932914021', 'Definitely']
# ['Pascal', '532', 'Unlikely']
# ['Lisp', '1522', 'Uncertain']
# ['D#', '12', 'Possibly']
# ['Cobol', '3', 'No.']
# ['Fortran', '52124', 'Yes.']
# ['Haskell', '24', 'lol.']

# %%
# adding a new row
new_row = soup.new_tag('tr')
new_data = soup.new_tag('td')
new_data.string = "New data"
new_row.append(new_data)
table.tbody.append(new_row)

# %%
row = [[i.text for i in row_.find_all('td')] for row_ in table.find_all('tr')]
for i in row:
    print(i)
# Out:
# []
# ['Python', '932914021', 'Definitely']
# ['Pascal', '532', 'Unlikely']
# ['Lisp', '1522', 'Uncertain']
# ['D#', '12', 'Possibly']
# ['Cobol', '3', 'No.']
# ['Fortran', '52124', 'Yes.']
# ['Haskell', '24', 'lol.']
# ['New data']

# %%
print(table.prettify())
# Out:
# <table style="width:100%">
#  <tbody>
#   <tr>
#    <th>
#     Program Name
#    </th>
#    <th>
#     Internet Points
#    </th>
#    <th>
#     Kittens?
#    </th>
#   </tr>
#   <tr>
#    <td>
#     Python
#    </td>
#    <td>
#     932914021
#    </td>
#    <td>
#     Definitely
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Pascal
#    </td>
#    <td>
#     532
#    </td>
#    <td>
#     Unlikely
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Lisp
#    </td>
#    <td>
#     1522
#    </td>
#    <td>
#     Uncertain
#    </td>
#   </tr>
#   <tr>
#    <td>
#     D#
#    </td>
#    <td>
#     12
#    </td>
#    <td>
#     Possibly
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Cobol
#    </td>
#    <td>
#     3
#    </td>
#    <td>
#     No.
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Fortran
#    </td>
#    <td>
#     52124
#    </td>
#    <td>
#     Yes.
#    </td>
#   </tr>
#   <tr>
#    <td>
#     Haskell
#    </td>
#    <td>
#     24
#    </td>
#    <td>
#     lol.
#    </td>
# ...

# %% [markdown]
# ### Program 3: Link Extraction from Sitemaps (Uses xml)

# %%
#PyQt
url = 'https://www.washingtonpost.com/news-sitemaps/index.xml'
doc = requests.get(url)
soup = make_soup(doc.content, 'xml')

# %%
soup
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <sitemapindex xmlns="http://www.sitemaps.org/schemas/sitemap/0.9">
# <sitemap>
# <loc>
# https://www.washingtonpost.com/news-sitemaps/politics.xml
# </loc>
# </sitemap>
# <sitemap>
# <loc>
# https://www.washingtonpost.com/news-sitemaps/opinions.xml
# </loc>
# </sitemap>
# <sitemap>
# <loc>
# https://www.washingtonpost.com/news-sitemaps/local.xml
# </loc>
# </sitemap>
# <sitemap>
# <loc>
# https://www.washingtonpost.com/news-sitemaps/sports.xml
# </loc>
# </sitemap>
# <sitemap>
# <loc>
# https://www.washingtonpost.com/news-sitemaps/national.xml
# </loc>
# </sitemap>
# <sitemap>
# <loc>
# https://www.washingtonpost.com/news-sitemaps/world.xml
# </loc>
# </sitemap>
# <sitemap>
# <loc>
# https://www.washingtonpost.com/news-sitemaps/business.xml
# </loc>
# </sitemap>
# <sitemap>
# <loc>
# https://www.washingtonpost.com/news-sitemaps/technology.xml
# </loc>
# </sitemap>
# <sitemap>
# <loc>
# ...

# %%
for i in soup.find_all('loc'):
    print(i.text)
# Out:
# https://www.washingtonpost.com/news-sitemaps/politics.xml
#
#
# https://www.washingtonpost.com/news-sitemaps/opinions.xml
#
#
# https://www.washingtonpost.com/news-sitemaps/local.xml
#
#
# https://www.washingtonpost.com/news-sitemaps/sports.xml
#
#
# https://www.washingtonpost.com/news-sitemaps/national.xml
#
#
# https://www.washingtonpost.com/news-sitemaps/world.xml
#
#
# https://www.washingtonpost.com/news-sitemaps/business.xml
#
#
# https://www.washingtonpost.com/news-sitemaps/technology.xml
#
#
# https://www.washingtonpost.com/news-sitemaps/lifestyle.xml
#
#
# https://www.washingtonpost.com/news-sitemaps/entertainment.xml
#
#
# https://www.washingtonpost.com/news-sitemaps/goingoutguide.xml
